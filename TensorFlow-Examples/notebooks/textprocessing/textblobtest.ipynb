# %% [markdown]
# Text blob test

# %% [markdown]
# load some text

# %%
from textblob import TextBlob
import numpy as np
import os
import time

import nltk

nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('brown')
# Out:
# [nltk_data] Downloading package punkt to /home/jupyter/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/jupyter/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package brown to /home/jupyter/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# True

# %%
path_to_file='../../../../mostsolarpapers/wavs_mag_solaratmos_fromlocalmagflux_2_bogdan_2003.txt'

# %%
# Read, then decode for py2 compat.
#text = open(path_to_file, 'rb').read().decode(encoding='utf-8')

text = open(path_to_file, 'rb').read().decode('windows-1252')
# length of text is the number of characters in it

newtext=text.strip()

# %%
blob = TextBlob(newtext)
blob.tags           # [('The', 'DT'), ('titular', 'JJ'),
                    #  ('threat', 'NN'), ('of', 'IN'), ...]
# Out:
# [('The', 'DT'),
#  ('Astrophysical', 'NNP'),
#  ('Journal', 'NNP'),
#  ('599:626\xad660', 'CD'),
#  ('2003', 'CD'),
#  ('December', 'NNP'),
#  ('10', 'CD'),
#  ('2003', 'CD'),
#  ('The', 'DT'),
#  ('American', 'JJ'),
#  ('Astronomical', 'NNP'),
#  ('Society', 'NNP'),
#  ('All', 'DT'),
#  ('rights', 'NNS'),
#  ('reserved', 'VBN'),
#  ('Printed', 'VBN'),
#  ('in', 'IN'),
#  ('U.S.A', 'NNP'),
#  ('WAVES', 'NNP'),
#  ('IN', 'NNP'),
#  ('THE', 'NNP'),
#  ('MAGNETIZED', 'NNP'),
#  ('SOLAR', 'NNP'),
#  ('ATMOSPHERE', 'NNP'),
#  ('II', 'NNP'),
#  ('WAVES', 'NNP'),
#  ('FROM', 'NNP'),
#  ('LOCALIZED', 'NNP'),
#  ('SOURCES', 'NNP'),
#  ('IN', 'NNP'),
#  ('MAGNETIC', 'NNP'),
#  ('FLUX', 'NNP'),
#  ('CONCENTRATIONS', 'NNP'),
#  ('T.', 'NNP'),
#  ('J.', 'NNP'),
#  ('Bogdan1', 'NNP'),
#  ('National', 'NNP'),
#  ('Science', 'NNP'),
#  ('Foundation', 'NNP'),
#  ('Arlington', 'NNP'),
#  ('VA', 'NNP'),
#  ('22203', 'CD'),
#  ('and', 'CC'),
#  ('E.', 'NNP'),
#  ('O.', 'NNP'),
#  ('Hulbert', 'NNP'),
#  ('Center', 'NNP'),
#  ('for', 'IN'),
#  ('Space', 'NNP'),
#  ('Research', 'NNP'),
#  ('Naval', 'NNP'),
#  ('Research', 'NNP'),
#  ('Laboratory', 'NNP'),
#  ('4555', 'CD'),
#  ('Overlook', 'NNP'),
#  ('Avenue', 'NNP'),
#  ('SW', 'NNP'),
#  ('Washington', 'NNP'),
#  ('DC', 'NNP'),
#  ('20375', 'CD'),
#  ('M.', 'NNP'),
#  ('Carlsson', 'NNP'),
#  ('V.', 'NNP'),
#  ('Hansteen', 'NNP'),
#  ('A.', 'NNP'),
#  ('McMurry', 'NNP'),
#  ('and', 'CC'),
#  ('C.', 'NNP'),
#  ('S.', 'NNP'),
#  ('Rosenthal2', 'NNP'),
#  ('Institute', 'NNP'),
#  ('of', 'IN'),
#  ('Theoretical', 'NNP'),
#  ('Astrophysics', 'NNP'),
#  ('University', 'NNP'),
#  ('of', 'IN'),
#  ('Oslo', 'NNP'),
#  ('P.O', 'NNP'),
#  ('Box', 'NN'),
#  ('1029', 'CD'),
#  ('Blindern', 'NNP'),
#  ('Oslo', 'NNP'),
#  ('N-0315', 'NNP'),
#  ('Norway', 'NNP'),
#  ('M.', 'NNP'),
#  ('Johnson', 'NNP'),
#  ('S.', 'NNP'),
#  ('Petty-Powell', 'NNP'),
#  ('and', 'CC'),
#  ('E.', 'NNP'),
#  ('J.', 'NNP'),
#  ('Zita', 'NNP'),
#  ('Evergreen', 'NNP'),
#  ('State', 'NNP'),
#  ('College', 'NNP'),
#  ('Olympia', 'NNP'),
#  ('WA', 'NNP'),
#  ('98505', 'CD'),
#  ('R.', 'NNP'),
#  ('F.', 'NNP'),
#  ('Stein', 'NNP'),
#  ('Department', 'NNP'),
#  ('of', 'IN'),
#  ('Physics', 'NNP'),
#  ('and', 'CC'),
#  ('Astronomy', 'NNP'),
#  ('Michigan', 'NNP'),
#  ('State', 'NNP'),
#  ('University', 'NNP'),
#  ('East', 'NNP'),
#  ('Lansing', 'NNP'),
#  ('MI', 'NNP'),
#  ('48824-1116', 'CD'),
#  ('S.', 'NNP'),
#  ('W.', 'NNP'),
#  ('McIntosh', 'NNP'),
#  ('Laboratory', 'NNP'),
#  ('for', 'IN'),
#  ('Astronomy', 'NNP'),
#  ('and', 'CC'),
#  ('Solar', 'NNP'),
#  ('Physics', 'NNP'),
#  ('NASA', 'NNP'),
#  ('Goddard', 'NNP'),
#  ('Space', 'NNP'),
#  ('Flight', 'NNP'),
#  ('Center', 'NNP'),
#  ('Greenbelt', 'NNP'),
#  ('MD', 'NNP'),
#  ('20771', 'CD'),
#  ('and', 'CC'),
#  ('Universities', 'NNPS'),
#  ('Space', 'NNP'),
#  ('Research', 'NNP'),
#  ('Association', 'NNP'),
#  ('CPSS', 'NNP'),
#  ('Seabrook', 'NNP'),
#  ('MD', 'NNP'),
#  ('20770', 'CD'),
#  ('and', 'CC'),
#  ('°', 'NNP'),
#  ('A.', 'NNP'),
#  ('Nordlund', 'NNP'),
#  ('Niels', 'NNP'),
#  ('Bohr', 'NNP'),
#  ('Institute', 'NNP'),
#  ('for', 'IN'),
#  ('Astronomy', 'NNP'),
#  ('Physics', 'NNP'),
#  ('and', 'CC'),
#  ('Geophysics', 'NNP'),
#  ('Københavns', 'NNP'),
#  ('Universitet', 'NNP'),
#  ('Blegdamsveg', 'NNP'),
#  ('17', 'CD'),
#  ('Copenhagen', 'NNP'),
#  ('Ø', 'NNP'),
#  ('DK-2100', 'NNP'),
#  ('Denmark', 'NNP'),
#  ('Received', 'NNP'),
#  ('2003', 'CD'),
#  ('March', 'NNP'),
#  ('19', 'CD'),
#  ('accepted', 'JJ'),
#  ('2003', 'CD'),
#  ('July', 'NNP'),
#  ('16', 'CD'),
#  ('ABSTRACT', 'NNP'),
#  ('Numerical', 'NNP'),
#  ('simulations', 'NNS'),
#  ('of', 'IN'),
#  ('wave', 'JJ'),
#  ('propagation', 'NN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('two-dimensional', 'JJ'),
#  ('stratified', 'JJ'),
#  ('magneto-atmosphere', 'NNS'),
#  ('are', 'VBP'),
#  ('presented', 'VBN'),
#  ('for', 'IN'),
#  ('conditions', 'NNS'),
#  ('that', 'WDT'),
#  ('are', 'VBP'),
#  ('representative', 'JJ'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('solar', 'NN'),
#  ('photosphere', 'NN'),
#  ('and', 'CC'),
#  ('chromosphere', 'NN'),
#  ('Both', 'DT'),
#  ('the', 'DT'),
#  ('emergent', 'JJ'),
#  ('magnetic', 'JJ'),
#  ('flux', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('extent', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('wave', 'NN'),
#  ('source', 'NN'),
#  ('are', 'VBP'),
#  ('spatially', 'RB'),
#  ('localized', 'VBN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('lower', 'JJR'),
#  ('photospheric', 'JJ'),
#  ('boundary', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('simulation', 'NN'),
#  ('The', 'DT'),
#  ('calculations', 'NNS'),
#  ('show', 'VBP'),
#  ('that', 'IN'),
#  ('the', 'DT'),
#  ('coupling', 'NN'),
#  ('between', 'IN'),
#  ('the', 'DT'),
#  ('fast', 'JJ'),
#  ('and', 'CC'),
#  ('slow', 'JJ'),
#  ('magnetoacoustic-gravity', 'NN'),
#  ('MAG', 'NNP'),
#  ('waves', 'VBZ'),
#  ('is', 'VBZ'),
#  ('confined', 'VBN'),
#  ('to', 'TO'),
#  ('thin', 'VB'),
#  ('quasi\xadone-dimensional', 'JJ'),
#  ('atmospheric', 'JJ'),
#  ('layers', 'NNS'),
#  ('where', 'WRB'),
#  ('the', 'DT'),
#  ('´', 'NNP'),
#  ('n', 'JJ'),
#  ('velocity', 'NN'),
#  ('are', 'VBP'),
#  ('comparable', 'JJ'),
#  ('in', 'IN'),
#  ('magnitude', 'NN'),
#  ('Away', 'RB'),
#  ('from', 'IN'),
#  ('this', 'DT'),
#  ('wave', 'NN'),
#  ('conversion', 'NN'),
#  ('zone', 'NN'),
#  ('sound', 'JJ'),
#  ('speed', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Alfve', 'NNP'),
#  ('which', 'WDT'),
#  ('we', 'PRP'),
#  ('call', 'VBP'),
#  ('the', 'DT'),
#  ('magnetic', 'JJ'),
#  ('canopy', 'NN'),
#  ('the', 'DT'),
#  ('two', 'CD'),
#  ('MAG', 'NNP'),
#  ('waves', 'NNS'),
#  ('are', 'VBP'),
#  ('effectively', 'RB'),
#  ('decoupled', 'VBN'),
#  ('because', 'IN'),
#  ('either', 'CC'),
#  ('the', 'DT'),
#  ('magnetic', 'JJ'),
#  ('pressure', 'NN'),
#  ('B2', 'NNP'),
#  ('=8', 'NNP'),
#  ('or', 'CC'),
#  ('the', 'DT'),
#  ('plasma', 'JJ'),
#  ('pressure', 'NN'),
#  ('p', 'JJ'),
#  ('¼', 'NNP'),
#  ('NkB', 'NNP'),
#  ('T', 'NNP'),
#  ('dominates', 'VBZ'),
#  ('over', 'IN'),
#  ('the', 'DT'),
#  ('other', 'JJ'),
#  ('The', 'DT'),
#  ('character', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('fluctuations', 'NNS'),
#  ('observed', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('magneto-atmosphere', 'JJ'),
#  ('depend', 'NN'),
#  ('sensitively', 'RB'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('relative', 'JJ'),
#  ('location', 'NN'),
#  ('and', 'CC'),
#  ('orientation', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('magnetic', 'JJ'),
#  ('canopy', 'NN'),
#  ('with', 'IN'),
#  ('respect', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('wave', 'NN'),
#  ('source', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('observation', 'NN'),
#  ('point', 'NN'),
#  ('Several', 'JJ'),
#  ('distinct', 'NNS'),
#  ('wave', 'VBP'),
#  ('trains', 'NNS'),
#  ('may', 'MD'),
#  ('converge', 'VB'),
#  ('on', 'IN'),
#  ('and', 'CC'),
#  ('simultaneously', 'RB'),
#  ('pass', 'VBP'),
#  ('through', 'IN'),
#  ('a', 'DT'),
#  ('given', 'VBN'),
#  ('location', 'NN'),
#  ('Their', 'PRP$'),
#  ('coherent', 'NN'),
#  ('superposition', 'NN'),
#  ('presents', 'VBZ'),
#  ('a', 'DT'),
#  ('bewildering', 'JJ'),
#  ('variety', 'NN'),
#  ('of', 'IN'),
#  ('Doppler', 'NNP'),
#  ('and', 'CC'),
#  ('intensity', 'NN'),
#  ('time', 'NN'),
#  ('series', 'NN'),
#  ('because', 'IN'),
#  ('1', 'CD'),
#  ('some', 'DT'),
#  ('waves', 'NNS'),
#  ('come', 'VBP'),
#  ('directly', 'RB'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('source', 'NN'),
#  ('while', 'IN'),
#  ('others', 'NNS'),
#  ('emerge', 'VBP'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('magnetic', 'JJ'),
#  ('canopy', 'NN'),
#  ('following', 'VBG'),
#  ('mode', 'NN'),
#  ('conversion', 'NN'),
#  ('2', 'CD'),
#  ('the', 'DT'),
#  ('propagation', 'NN'),
#  ('directions', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('individual', 'JJ'),
#  ('wave', 'NN'),
#  ('trains', 'NNS'),
#  ('are', 'VBP'),
#  ('neither', 'DT'),
#  ('co-aligned', 'JJ'),
#  ('with', 'IN'),
#  ('each', 'DT'),
#  ('other', 'JJ'),
#  ('nor', 'CC'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('observer', 'NN'),
#  ("'s", 'POS'),
#  ('line', 'NN'),
#  ('of', 'IN'),
#  ('sight', 'NN'),
#  ('and', 'CC'),
#  ('3', 'CD'),
#  ('the', 'DT'),
#  ('wave', 'NN'),
#  ('trains', 'NNS'),
#  ('may', 'MD'),
#  ('be', 'VB'),
#  ('either', 'CC'),
#  ('fast', 'VB'),
#  ('or', 'CC'),
#  ('slow', 'VB'),
#  ('MAG', 'NNP'),
#  ('waves', 'NNS'),
#  ('that', 'WDT'),
#  ('exhibit', 'VBP'),
#  ('different', 'JJ'),
#  ('characteristics', 'NNS'),
#  ('depending', 'VBG'),
#  ('on', 'IN'),
#  ('whether', 'IN'),
#  ('they', 'PRP'),
#  ('are', 'VBP'),
#  ('observed', 'VBN'),
#  ('in', 'IN'),
#  ('high-', 'JJ'),
#  ('or', 'CC'),
#  ('low-', 'JJ'),
#  ('plasmas', 'NN'),
#  ('8p=B2', 'CD'),
#  ('Through', 'IN'),
#  ('the', 'DT'),
#  ('analysis', 'NN'),
#  ('of', 'IN'),
#  ('four', 'CD'),
#  ('numerical', 'JJ'),
#  ('experiments', 'NNS'),
#  ('a', 'DT'),
#  ('coherent', 'NN'),
#  ('and', 'CC'),
#  ('physically', 'RB'),
#  ('intuitive', 'JJ'),
#  ('picture', 'NN'),
#  ('emerges', 'NNS'),
#  ('of', 'IN'),
#  ('how', 'WRB'),
#  ('fast', 'JJ'),
#  ('and', 'CC'),
#  ('slow', 'JJ'),
#  ('MAG', 'NNP'),
#  ('waves', 'NNS'),
#  ('interact', 'VBP'),
#  ('within', 'IN'),
#  ('two-dimensional', 'JJ'),
#  ('magneto-atmospheres', 'NNS'),
#  ('Subject', 'JJ'),
#  ('headings', 'NNS'),
#  ('MHD', 'NNP'),
#  ('Sun', 'NNP'),
#  ('chromosphere', 'NN'),
#  ('Sun', 'NNP'),
#  ('magnetic', 'JJ'),
#  ('fields', 'NNS'),
#  ('Sun', 'NNP'),
#  ('oscillations', 'NNS'),
#  ('sunspots', 'VBD'),
#  ('1', 'CD'),
#  ('INTRODUCTION', 'NN'),
#  ('This', 'DT'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('second', 'JJ'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('projected', 'JJ'),
#  ('series', 'NN'),
#  ('of', 'IN'),
#  ('papers', 'NNS'),
#  ('that', 'WDT'),
#  ('explores', 'VBZ'),
#  ('the', 'DT'),
#  ('basic', 'JJ'),
#  ('physics', 'NNS'),
#  ('of', 'IN'),
#  ('wave', 'JJ'),
#  ('propagation', 'NN'),
#  ('in', 'IN'),
#  ('stratified', 'JJ'),
#  ('magneto-atmospheres', 'NNS'),
#  ('In', 'IN'),
#  ('the', 'DT'),
#  ('previous', 'JJ'),
#  ('contribution', 'NN'),
#  ('Rosenthal', 'NNP'),
#  ('et', 'RB'),
#  ('al', 'RB'),
#  ('2002', 'CD'),
#  ('hereafter', 'JJR'),
#  ('Paper', 'NNP'),
#  ('I', 'PRP'),
#  ('we', 'PRP'),
#  ('outlined', 'VBD'),
#  ('the', 'DT'),
#  ('basic', 'JJ'),
#  ('equilibrium', 'NN'),
#  ('configurations', 'NNS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('underlying', 'VBG'),
#  ('governing', 'NN'),
#  ('equations', 'NNS'),
#  ('that', 'WDT'),
#  ('form', 'VBP'),
#  ('the', 'DT'),
#  ('basis', 'NN'),
#  ('for', 'IN'),
#  ('this', 'DT'),
#  ('series', 'NN'),
#  ('We', 'PRP'),
#  ('also', 'RB'),
#  ('took', 'VBD'),
#  ('special', 'JJ'),
#  ('care', 'NN'),
#  ('to', 'TO'),
#  ('define', 'VB'),
#  ('the', 'DT'),
#  ('nomenclature', 'NN'),
#  ('used', 'VBN'),
#  ('to', 'TO'),
#  ('describe', 'VB'),
#  ('and', 'CC'),
#  ('identify', 'VB'),
#  ('the', 'DT'),
#  ('various', 'JJ'),
#  ('types', 'NNS'),
#  ('of', 'IN'),
#  ('waves', 'NNS'),
#  ('present', 'JJ'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('simulations', 'NNS'),
#  ('and', 'CC'),
#  ('in', 'IN'),
#  ('realistic', 'JJ'),
#  ('magneto-atmospheres', 'NNS'),
#  ('The', 'DT'),
#  ('essential', 'JJ'),
#  ('point', 'NN'),
#  ('to', 'TO'),
#  ('emerge', 'VB'),
#  ('from', 'IN'),
#  ('these', 'DT'),
#  ('discussions', 'NNS'),
#  ('is', 'VBZ'),
#  ('that', 'IN'),
#  ('it', 'PRP'),
#  ('makes', 'VBZ'),
#  ('sense', 'NN'),
#  ('to', 'TO'),
#  ('speak', 'VB'),
#  ('of', 'IN'),
#  ('fast', 'JJ'),
#  ('and', 'CC'),
#  ('slow', 'JJ'),
#  ('magneto1', 'NN'),
#  ('On', 'IN'),
#  ('leave', 'NN'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('High', 'NNP'),
#  ('Altitude', 'NNP'),
#  ('Observatory', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('National', 'NNP'),
#  ('Center', 'NNP'),
#  ('for', 'IN'),
#  ('Atmospheric', 'NNP'),
#  ('Research', 'NNP'),
#  ('through', 'IN'),
#  ('2003', 'CD'),
#  ('October', 'NNP'),
#  ('1', 'CD'),
#  ('2', 'CD'),
#  ('Current', 'JJ'),
#  ('address', 'NN'),
#  ('Soskraenten', 'JJ'),
#  ('58', 'CD'),
#  ('DK-8260', 'NNP'),
#  ('Viby', 'NNP'),
#  ('J', 'NNP'),
#  ('Denmark', 'NNP'),
#  ('acoustic-gravity', 'NN'),
#  ('MAG', 'NNP'),
#  ('waves', 'VBZ'),
#  ('within', 'IN'),
#  ('contiguous', 'JJ'),
#  ('regions', 'NNS'),
#  ('where', 'WRB'),
#  ('the', 'DT'),
#  ('plasma', 'NN'),
#  ('the', 'DT'),
#  ('ratio', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('thermal', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('magnetic', 'JJ'),
#  ('pressure', 'NN'),
#  ('viz.', 'NN'),
#  ('8p=B2', 'CD'),
#  ('is', 'VBZ'),
#  ('everywhere', 'RB'),
#  ('much', 'JJ'),
#  ('greater', 'JJR'),
#  ('or', 'CC'),
#  ('much', 'RB'),
#  ('smaller', 'JJR'),
#  ('than', 'IN'),
#  ('unity', 'NN'),
#  ('However', 'RB'),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('possible', 'JJ'),
#  ('to', 'TO'),
#  ('continue', 'VB'),
#  ('such', 'JJ'),
#  ('identifications', 'NNS'),
#  ('across', 'IN'),
#  ('atmospheric', 'JJ'),
#  ('layers', 'NNS'),
#  ('where', 'WRB'),
#  ('%', 'NN'),
#  ('1', 'CD'),
#  ('because', 'IN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('ubiquitous', 'JJ'),
#  ('wave', 'NN'),
#  ('mixing', 'NN'),
#  ('and', 'CC'),
#  ('transformation', 'NN'),
#  ('that', 'IN'),
#  ('occur', 'VBP'),
#  ('there', 'RB'),
#  ('We', 'PRP'),
#  ('shall', 'MD'),
#  ('continue', 'VB'),
#  ('the', 'DT'),
#  ('practice', 'NN'),
#  ('established', 'VBN'),
#  ('in', 'IN'),
#  ('Paper', 'NNP'),
#  ('I', 'PRP'),
#  ('of', 'IN'),
#  ('simply', 'RB'),
#  ('referring', 'VBG'),
#  ('to', 'TO'),
#  ('this', 'DT'),
#  ('mixing', 'VBG'),
#  ('layer', 'NN'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('magnetic', 'JJ'),
#  ('canopy', 'NN'),
#  ('The', 'DT'),
#  ('physical', 'JJ'),
#  ('principles', 'NNS'),
#  ('that', 'WDT'),
#  ('underlie', 'VBP'),
#  ('the', 'DT'),
#  ('linear', 'JJ'),
#  ('mixing', 'NN'),
#  ('of', 'IN'),
#  ('fast', 'NN'),
#  ('and', 'CC'),
#  ('slow', 'VB'),
#  ('MAG', 'NNP'),
#  ('waves', 'NNS'),
#  ('have', 'VBP'),
#  ('been', 'VBN'),
#  ('known', 'VBN'),
#  ('for', 'IN'),
#  ('some', 'DT'),
#  ('time', 'NN'),
#  ('´', 'JJ'),
#  ('n', 'JJ'),
#  ('velocity', 'NN'),
#  ('and', 'CC'),
#  ('Ferraro', 'NNP'),
#  ('&', 'CC'),
#  ('Plumpton', 'NNP'),
#  ('1958', 'CD'),
#  ('Where', 'WRB'),
#  ('the', 'DT'),
#  ('Alfve', 'NNP'),
#  ('the', 'DT'),
#  ('sound', 'NN'),
#  ('speed', 'NN'),
#  ('are', 'VBP'),
#  ('disparate', 'NN'),
#  ('the', 'DT'),
#  ('two', 'CD'),
#  ('waves', 'NNS'),
#  ('are', 'VBP'),
#  ('decoupled', 'VBN'),
#  ('with', 'IN'),
#  ('one', 'CD'),
#  ('having', 'VBG'),
#  ('a', 'DT'),
#  ('dominant', 'JJ'),
#  ('magnetic', 'JJ'),
#  ('character', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('other', 'JJ'),
#  ('being', 'VBG'),
#  ('mostly', 'RB'),
#  ('acoustic', 'JJ'),
#  ('in', 'IN'),
#  ('nature', 'NN'),
#  ('However', 'RB'),
#  ('when', 'WRB'),
#  ('´', 'NN'),
#  ('n', 'JJ'),
#  ('velocity', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('sound', 'NN'),
#  ('speed', 'NN'),
#  ('are', 'VBP'),
#  ('comparable', 'JJ'),
#  ('the', 'DT'),
#  ('the', 'DT'),
#  ('Alfve', 'NNP'),
#  ('waves', 'VBZ'),
#  ('become', 'VBN'),
#  ('alike', 'RB'),
#  ('which', 'WDT'),
#  ('means', 'VBZ'),
#  ('that', 'IN'),
#  ('they', 'PRP'),
#  ('show', 'VBP'),
#  ('both', 'DT'),
#  ('626', 'CD'),
#  ('WAVES', 'NNP'),
#  ('IN', 'NNP'),
#  ('MAGNETIZED', 'NNP'),
#  ('SOLAR', 'NNP'),
#  ('ATMOSPHERE', 'NNP'),
#  ('II', 'NNP'),
#  ('acoustic', 'JJ'),
#  ('and', 'CC'),
#  ('magnetic', 'JJ'),
#  ('qualities', 'NNS'),
#  ('and', 'CC'),
#  ('this', 'DT'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('cause', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('mixing', 'NN'),
#  ('The', 'DT'),
#  ('waves', 'NNS'),
#  ('approach', 'VBP'),
#  ('the', 'DT'),
#  ('canopy', 'NN'),
#  ('as', 'IN'),
#  ('separate', 'JJ'),
#  ('entities', 'NNS'),
#  ('they', 'PRP'),
#  ('become', 'VBP'),
#  ('alike', 'JJ'),
#  ('inside', 'IN'),
#  ('the', 'DT'),
#  ('canopy', 'NN'),
#  ('and', 'CC'),
#  ('emerge', 'NN'),
#  ('from', 'IN'),
#  ('it', 'PRP'),
#  ('as', 'IN'),
#  ('separate', 'JJ'),
#  ('waves', 'NNS'),
#  ('again', 'RB'),
#  ('with', 'IN'),
#  ('exchanged', 'JJ'),
#  ('identities', 'NNS'),
#  ('i.e.', 'FW'),
#  ('transformed', 'VBD'),
#  ('one', 'CD'),
#  ('into', 'IN'),
#  ('the', 'DT'),
#  ('other', 'JJ'),
#  ('Z.', 'NNP'),
#  ('E.', 'NNP'),
#  ('Musielak', 'NNP'),
#  ('2003', 'CD'),
#  ('private', 'JJ'),
#  ('communication', 'NN'),
#  ('The', 'DT'),
#  ('essential', 'JJ'),
#  ('finding', 'NN'),
#  ('of', 'IN'),
#  ('this', 'DT'),
#  ('investigation', 'NN'),
#  ('is', 'VBZ'),
#  ('simply', 'RB'),
#  ('that', 'IN'),
#  ('this', 'DT'),
#  ('fundamental', 'JJ'),
#  ('concept', 'NN'),
#  ('of', 'IN'),
#  ('wave', 'NN'),
#  ('mixing', 'NN'),
#  ('and', 'CC'),
#  ('transformation', 'NN'),
#  ('remains', 'VBZ'),
#  ('valid', 'JJ'),
#  ('in', 'IN'),
#  ('two-dimensional', 'JJ'),
#  ('magnetic', 'JJ'),
#  ('field', 'NN'),
#  ('geometries', 'NNS'),
#  ('In', 'IN'),
#  ('this', 'DT'),
#  ('paper', 'NN'),
#  ('we', 'PRP'),
#  ('focus', 'VBP'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('behavior', 'NN'),
#  ('of', 'IN'),
#  ('monochromatic', 'JJ'),
#  ('waves', 'NNS'),
#  ('emanating', 'VBG'),
#  ('from', 'IN'),
#  ('spatially', 'RB'),
#  ('localized', 'VBN'),
#  ('Dx', 'NNP'),
#  ('%', 'NN'),
#  ('H', 'NNP'),
#  ('and', 'CC'),
#  ('temporally', 'RB'),
#  ('coherent', 'JJ'),
#  ('lifetime', 'JJ'),
#  ('4', 'CD'),
#  ('period', 'NN'),
#  ('sources', 'NNS'),
#  ('The', 'DT'),
#  ('salient', 'JJ'),
#  ('property', 'NN'),
#  ('of', 'IN'),
#  ('such', 'JJ'),
#  ('wave', 'NN'),
#  ('trains', 'NNS'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('complex', 'JJ'),
#  ('interference', 'NN'),
#  ('patterns', 'NNS'),
#  ('that', 'WDT'),
#  ('develop', 'VBP'),
#  ('between', 'IN'),
#  ('the', 'DT'),
#  ('different', 'JJ'),
#  ('wave', 'NN'),
#  ('types', 'NNS'),
#  ('emitted', 'VBN'),
#  ('directly', 'RB'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('source', 'NN'),
#  ('and', 'CC'),
#  ('those', 'DT'),
#  ('emerging', 'VBG'),
#  ('following', 'VBG'),
#  ('transformation', 'NN'),
#  ('at', 'IN'),
#  ('nearby', 'JJ'),
#  ('%', 'NN'),
#  ('1', 'CD'),
#  ('magnetic', 'JJ'),
#  ('canopy', 'NN'),
#  ('layers', 'NNS'),
#  ('Waves', 'NNS'),
#  ('that', 'WDT'),
#  ('arrive', 'VBP'),
#  ('at', 'IN'),
#  ('a', 'DT'),
#  ('particular', 'JJ'),
#  ('atmospheric', 'JJ'),
#  ('location', 'NN'),
#  ('may', 'MD'),
#  ('have', 'VB'),
#  ('left', 'VBN'),
#  ('the', 'DT'),
#  ('source', 'NN'),
#  ('region', 'NN'),
#  ('at', 'IN'),
#  ('different', 'JJ'),
#  ('times', 'NNS'),
#  ('and', 'CC'),
#  ('often', 'RB'),
#  ('take', 'VBP'),
#  ('rather', 'RB'),
#  ('distinct', 'JJ'),
#  ('routes', 'NNS'),
#  ('in', 'IN'),
#  ('transit', 'NN'),
#  ('This', 'DT'),
#  ('occurs', 'VBZ'),
#  ('largely', 'RB'),
#  ('on', 'IN'),
#  ('account', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('great', 'JJ'),
#  ('disparities', 'NNS'),
#  ('between', 'IN'),
#  ('the', 'DT'),
#  ('sound', 'NN'),
#  ('speed', 'NN'),
#  ('´', 'NNP'),
#  ('n', 'CC'),
#  ('velocity', 'NN'),
#  ('[', 'VBP'),
#  ('a', 'DT'),
#  ('B=ð4Þ1=2', 'NNP'),
#  (']', 'NN'),
#  ('[', 'JJ'),
#  ('c', 'NN'),
#  ('ð', 'NNP'),
#  ('p=Þ1=2', 'NN'),
#  (']', 'NN'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('Alfve', 'NNP'),
#  ('We', 'PRP'),
#  ('select', 'VBP'),
#  ('a', 'DT'),
#  ('single', 'JJ'),
#  ('driving', 'NN'),
#  ('frequency', 'NN'),
#  ('that', 'WDT'),
#  ('is', 'VBZ'),
#  ('about', 'RB'),
#  ('10', 'CD'),
#  ('times', 'NNS'),
#  ('larger', 'JJR'),
#  ('than', 'IN'),
#  ('the', 'DT'),
#  ('acoustic', 'JJ'),
#  ('cutoff', 'NN'),
#  ('frequency', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('magneto-atmosphere', 'JJ'),
#  ('Given', 'VBN'),
#  ('the', 'DT'),
#  ('preliminary', 'JJ'),
#  ('character', 'NN'),
#  ('of', 'IN'),
#  ('our', 'PRP$'),
#  ('direct', 'JJ'),
#  ('numerical', 'JJ'),
#  ('simulations', 'NNS'),
#  ('of', 'IN'),
#  ('waves', 'NNS'),
#  ('in', 'IN'),
#  ('two-dimensional', 'JJ'),
#  ('equilibria', 'NNS'),
#  ('we', 'PRP'),
#  ('believe', 'VBP'),
#  ('there', 'EX'),
#  ('is', 'VBZ'),
#  ('little', 'JJ'),
#  ('justification', 'NN'),
#  ('for', 'IN'),
#  ('treating', 'VBG'),
#  ('a', 'DT'),
#  ('realistic', 'JJ'),
#  ('stochastic', 'JJ'),
#  ('driving', 'NN'),
#  ('process', 'NN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('broad', 'JJ'),
#  ('spectrum', 'NN'),
#  ('of', 'IN'),
#  ('frequencies', 'NNS'),
#  ('Instead', 'RB'),
#  ('we', 'PRP'),
#  ('simply', 'RB'),
#  ('regard', 'VB'),
#  ('the', 'DT'),
#  ('monochromatic', 'JJ'),
#  ('driving', 'NN'),
#  ('studied', 'VBN'),
#  ('here', 'RB'),
#  ('as', 'IN'),
#  ('being', 'VBG'),
#  ('representative', 'JJ'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('very', 'RB'),
#  ('qualitative', 'JJ'),
#  ('sense', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('high-frequency', 'NN'),
#  ('say', 'VB'),
#  ...]

# %%
blob.noun_phrases   # WordList(['titular threat', 'blob',
                    #            'ultimate movie monster',
                    #            'amoeba-like mass', ...])

# %%
for sentence in blob.sentences:
    print(sentence)
    print(sentence.sentiment.polarity)
# Out:
# The Astrophysical Journal, 599:626­660, 2003 December 10
# # 2003.
# 0.0
# The American Astronomical Society.
# 0.0
# All rights reserved.
# 0.0
# Printed in U.S.A.
# 0.0
# WAVES IN THE MAGNETIZED SOLAR ATMOSPHERE.
# 0.0
# II.
# 0.0
# WAVES FROM LOCALIZED SOURCES IN MAGNETIC FLUX CONCENTRATIONS T. J. Bogdan1
# National Science Foundation, Arlington, VA 22203; and E. O. Hulbert Center for Space Research, Naval Research Laboratory, 4555 Overlook Avenue, SW, Washington, DC 20375
#
# M. Carlsson V. Hansteen, A. McMurry, and C. S. Rosenthal2
# Institute of Theoretical Astrophysics, University of Oslo, P.O.
# -0.05
# Box 1029, Blindern, Oslo, N-0315, Norway
#
# M. Johnson, S. Petty-Powell, and E. J. Zita
# Evergreen State College, Olympia, WA 98505
#
# R. F. Stein
# Department of Physics and Astronomy, Michigan State University, East Lansing, MI 48824-1116
#
# S. W. McIntosh
# Laboratory for Astronomy and Solar Physics, NASA Goddard Space Flight Center, Greenbelt, MD 20771; and Universities Space Research Association, CPSS, Seabrook, MD 20770
#
# and ° A. Nordlund
# Niels Bohr Institute for Astronomy, Physics and Geophysics, Københavns Universitet, Blegdamsveg 17, Copenhagen Ø, DK-2100, Denmark Received 2003 March 19; accepted 2003 July 16
#
# ABSTRACT Numerical simulations of wave propagation in a two-dimensional stratified magneto-atmosphere are presented for conditions that are representative of the solar photosphere and chromosphere.
# -0.1
# Both the emergent magnetic flux and the extent of the wave source are spatially localized at the lower photospheric boundary of the simulation.
# 0.0
# The calculations show that the coupling between the fast and slow magnetoacoustic-gravity (MAG) waves is confined to thin quasi­one-dimensional atmospheric layers where the ´ n velocity are comparable in magnitude.
# -0.125
# Away from this wave conversion zone, sound speed and the Alfve which we call the magnetic canopy, the two MAG waves are effectively decoupled because either the magnetic pressure (B2 =8) or the plasma pressure (p ¼ NkB T ) dominates over the other.
# 0.34375
# The character of the fluctuations observed in the magneto-atmosphere depend sensitively on the relative location and orientation of the magnetic canopy with respect to the wave source and the observation point.
# 0.05
# Several distinct wave trains may converge on and simultaneously pass through a given location.
# 0.15
# Their coherent superposition presents a bewildering variety of Doppler and intensity time series because (1) some waves come directly from the source while others emerge from the magnetic canopy following mode conversion, (2) the propagation directions of the individual wave trains are neither co-aligned with each other nor with the observer's line of sight, and (3) the wave trains may be either fast or slow MAG waves that exhibit different characteristics depending on whether they are observed in high- or low- plasmas (  8p=B2 ).
# 0.053500000000000006
# Through the analysis of four numerical experiments a coherent and physically intuitive picture emerges of how fast and slow MAG waves interact within two-dimensional magneto-atmospheres.
# 0.059999999999999984
# Subject headings: MHD -- Sun: chromosphere -- Sun: magnetic fields -- Sun: oscillations -- sunspots
# 1.
# -0.16666666666666666
# INTRODUCTION
#
# This is the second in a projected series of papers that explores the basic physics of wave propagation in stratified magneto-atmospheres.
# 0.0
# In the previous contribution (Rosenthal et al.
# -0.16666666666666666
# 2002, hereafter Paper I) we outlined the basic equilibrium configurations and the underlying governing equations that form the basis for this series.
# 0.0
# We also took special care to define the nomenclature used to describe and identify the various types of waves present in the simulations and in realistic magneto-atmospheres.
# 0.13095238095238096
# The essential point to emerge from these discussions is that it makes sense to speak of fast and slow magneto1 On leave from the High Altitude Observatory of the National Center for Atmospheric Research through 2003 October 1.
# -0.006666666666666672
# 2 Current address: Soskraenten 58, DK-8260 Viby J, Denmark.
# 0.0
# acoustic-gravity (MAG) waves within contiguous regions where the plasma  , the ratio of the thermal to the magnetic pressure, viz., 8p=B2 , is everywhere much greater or much smaller than unity.
# 0.25
# However, it is not possible to continue such identifications across atmospheric layers where  % 1, because of the ubiquitous wave mixing and transformation that occur there.
# 0.0
# We shall continue the practice established in Paper I of simply referring to this mixing layer as the `` magnetic canopy.''
# 0.0
# The physical principles that underlie the linear mixing of fast and slow MAG waves have been known for some time ´ n velocity and (Ferraro & Plumpton 1958).
# -0.03333333333333335
# Where the Alfve the sound speed are disparate, the two waves are decoupled, with one having a dominant magnetic character, and the other being mostly acoustic in nature.
# 0.25833333333333336
# However, when ´ n velocity and the sound speed are comparable, the the Alfve waves become alike, which means that they show both 626
#
# WAVES IN MAGNETIZED SOLAR ATMOSPHERE.
# 0.4
# II.
# 0.0
# acoustic and magnetic qualities, and this is the cause of the mixing.
# 0.0
# The waves approach the canopy as separate entities; they become alike inside the canopy and emerge from it as separate waves again, with exchanged identities, i.e., transformed one into the other (Z. E. Musielak 2003, private communication).
# -0.0625
# The essential finding of this investigation is simply that this fundamental concept of wave mixing and transformation remains valid in two-dimensional magnetic field geometries.
# -0.03333333333333333
# In this paper, we focus on the behavior of monochromatic waves emanating from spatially localized (Dx % H ) and temporally coherent (lifetime 4 period) sources.
# 0.5
# The salient property of such wave trains is the complex interference patterns that develop between the different wave types emitted directly by the source and those emerging following transformation at nearby  % 1 magnetic canopy layers.
# -0.039999999999999994
# Waves that arrive at a particular atmospheric location may have left the source region at different times and often take rather distinct routes in transit.
# 0.09333333333333334
# This occurs largely on account of the great disparities between the sound speed ´ n velocity [a  B=ð4Þ1=2 ].
# 0.47142857142857136
#  p=Þ1=2 ] and the Alfve We select a single driving frequency that is about 10 times larger than the acoustic cutoff frequency of the magneto-atmosphere.
# -0.03571428571428571
# Given the preliminary character of our direct numerical simulations of waves in two-dimensional equilibria, we believe there is little justification for treating a realistic stochastic driving process with a broad spectrum of frequencies.
# 0.008333333333333331
# Instead, we simply regard the monochromatic driving studied here as being representative in a very qualitative sense of the high-frequency (say >30 mHz) tail of the solar turbulent spectrum.
# 0.1
# The calculations presented and analyzed here also underscore the fundamental role played by the magnetic canopy in shaping the spatial and temporal distribution of oscillatory phenomena in and around magnetic flux concentrations.
# 0.0
# The critical importance of the magnetic canopy for wave propagation was a central theme of Paper I.
# 0.0
# It continues to remain so in the present contribution, although new facets of its influence and function will subsequently emerge in what follows.
# 0.04545454545454545
# These numerical simulations are crucial for developing a physical context in which to discuss and interpret waves and oscillations in gravitationally stratified highly conducting astrophysical plasmas.
# 0.05333333333333334
# The specific examples studied here pertain to localized sources within magnetic flux concentrations.
# 0.0
# Parallels may readily be drawn to acoustic sources in the Sun's magnetic network and within isolated magnetic flux tubes, pores, knots, and sunspots.
# 0.2
# In fact, typical values adopted for the surface gravity, sound speed, and magnetic field strength are chosen to be commensurate with the prevailing solar surface conditions.
# 0.11666666666666668
# Similar application to latetype stars and planetary magnetospheres are subject to additional caveats, but a general level of correspondence is essentially retained.
# -0.02916666666666666
# We shall comment at length in the concluding section as to how these findings impact the interpretation of oscillation data from sunspots and the network.
# 0.0
# On the other hand, no effort will be made to model particular observation sequences or to create synthetic Stokes profiles.
# 0.02083333333333333
# Such exercises are premature and distract from the principal effort to fashion a basic physical foundation on which to build our understanding.
# 0.0
# It is our intent to address these practical and applied issues in forthcoming contributions.
# 0.0
# The later papers will eventually employ a sophisticated multidimensional radiative transfer calculation in lieu D
#
# 627
#
# of the condition of isentropy (DS =Dt ¼ @ S=@ t þ u x S ¼ 0).
# 0.25
# Direct comparisons with data will then be meaningful and informative.
# 0.3
# The pressing need for such a basic study of wave propagation in magneto-atmospheres is justified on both observational and theoretical grounds.
# 0.1
# In the solar atmosphere, for example, the waves and oscillations that one can readily detect have a characteristic wavelengths comparable to the scale of variation of the magnetic field.
# 0.06666666666666668
# This basic equality may well be a natural consequence of how the wave sources are influenced by the magnetic field.
# 0.05
# From a theoretical perspective this congruence of scales is unfortunate, since it renders ineffective several powerful techniques that have been developed to address situations in which the wavelength is much greater (i.e., virial methods and fine-grain averaging) or much smaller (i.e., eikonal and WKBJ methods) than the spatial scale of the background magnetic field (Barnes 1992;  adez  adez  & Ballester 1994; C  , Oliver, & Webb et al.
# 0.05714285714285715
# 1993; C Ballester 1996; Ruderman, Nakariakov, & Roberts 1998).
# 0.0
# Under these unfavorable circumstances, one has no other recourse than to develop accurate numerical solutions of the primitive equations, study these solutions with the aim of identifying certain unifying physical principles, and then devise analytic and numerical tools and strategies to bridge the gap between the provenance of the eikonal and effective medium approaches.
# 0.2553571428571429
# Other contributions to the literature have pursued a similar objective.
# -0.041666666666666664
# The recent publications by Shibata (1983), Oliver & Ballester (1995), Cargill, Spicer, & Zalesak (1997), Ofman & Davila (1998), Sakai, Igarashi, & Kawata (1998), Ofman, Nakariakov, & DeForest (1999), Terradas, Oliver,  il & Karlicky ´ (2000), Ofman, & Ballester (1999), Odstrc Nakariakov, & Sehgal (2000), Sakai et al.
# 0.0
# (2000, 2001), Bo & Wang (2001), and Oliver & Ballester (2002) present two-dimensional numerical simulations for a variety of magneto-atmospheres relevant for waves in coronal plumes, oscillations of magnetic prominences, Moreton and/or EIT waves, and general large-scale coronal dynamics.
# 0.08750000000000002
# Fully three-dimensional problems are tackled by Wu et al.
# 0.0
# (2001) and Ofman & Thompson (2002).
# 0.0
# In large part these studies are motivated by the desire to explain various remarkable observations or to circumscribe the degree to which linear and nonlinear MAG waves are capable of heating the atmosphere and driving sustained mass flows.
# 0.2910714285714286
# Within this framework, the simulations are chosen not so much for their pedagogical value as for their ability to mirror the complex reality of the solar atmosphere.
# -0.04999999999999999
# There is ample room for both philosophies within this subject.
# -0.16666666666666666
# Related studies that adopt a diverse array of simplifying assumptions are more prevalent, and it is impossible to cite all of them here.
# -0.055555555555555546
# The exact multidimensional simulations are essential for delimiting the circumstances under which these idealizations are valid.
# 0.125
# Some of the more popular approaches employ the magnetic field to reduce the effective spatial dimensionality of the problem (Mariska & Hollweg 1985; Sterling & Hollweg 1988; Kudoh & Shibata 1999; Nakariakov et al.
# 0.5666666666666668
# 2000; Saito, Kudoh, & Shibata 2001; Tsiklauri & Nakariakov 2001), take the cold plasma limit  !
# -0.75
# 0, which removes the  ¼ 1 magnetic canopy to infinity (Wright 1992; Walker 1998; Vogt 2002), or employ a nonphysical gravitational acceleration (Belie ¨ n, Poedts, & Goedbloed 1997; Belie ¨ n, Martens, & Keppens 1999).
# 0.0
# There is also a very well-developed literature on the problem of one-dimensional nonlinear wave propagation in
#
# 628
#
# BOGDAN ET AL.
# 0.2
# TABLE 1 Isothermal Atmosphere Parameters Quantity Temperature .................................. Density scale height........................ Adiabatic sound speed ...................
# 0.4
# Ratio of specific heats..................... Acoustic cutoff frequency............... Brunt-Va ¨ isa ¨ la ¨ frequency ................ Gravitational acceleration ............. Base pressure ................................. Base density ................................... Value
#
# Vol.
# -0.5333333333333333
# 599
#
# stratified atmospheres, which altogether neglects the magnetic field (Stein 1968; Einaudi 1969, 1970; Stein & Schwartz 1972, 1973; Cannon 1974; Schwartz & Stein 1975; Bois 1976; Klein, Stein, & Kalkofen 1978; Leibacher, Gouttebroze, & Stein 1982; Pelinovskii & Petrukhin 1988; Pelinovsky & Petrukhin 1994; Carlsson & Stein 1992, 1995, 1997, 2002; Schmitz & Fleck 1995; Theurer, Ulmschneider, & Cuntz 1997; Sutmann, Musielak, & Ulmschneider 1998).
# 0.0
# Two- and three-dimensional extensions of these studies are available, but with few notable exceptions they tend to focus exclusively on the linearized equations (Lamb 1908, 1910; Kato 1966; Cole & Greifinger 1969; Wait 1974; Yih 1974; Hammerton & Crighton 1989; Crighton & Lee-Bapty 1992; Borovikov 1996; Bodo et al.
# 0.2333333333333333
# 2000).
# 0.0
# In x 2 we provide an overview of the four numerical experiments that are the centerpiece of this paper.
# 0.0
# Each is represented by a cubic lattice of 294 Â 500 Â ð100 200Þ entries (i.e., altitude by horizontal distance by time) for every one of the six dependent variables (i.e., , p, B , and u).3 The bulk of the paper (x 3) is devoted to a discussion and a critical analysis of how the MAG waves interact with their environment.
# 0.0
# This discourse is somewhat lengthy and moderately technical in places, but what gradually emerges from the consideration of these different numerical experiments is a predictive analysis scheme that is applicable to a much richer class of two-dimensional magnetoatmospheres.
# 0.025
# We believe this system is portable and will therefore prove useful to theorists and observers alike.
# 0.3
# The transport and circulation of energy, a critical ingredient for assessing the role of wave heating of stellar atmospheres, is taken up in x 4.
# 0.125
# These deliberations prove to be largely unsatisfactory because the dominant component of the energy flux does not participate in the transfer of energy over large distances but is instead associated with stationary circulation patterns.
# 0.21428571428571427
# There is clear evidence for long-range transport of energy by MAG waves, but it is not possible to quantify in an unambiguous fashion.
# 0.05000000000000001
# We argue that a reliable determination of atmospheric heating by MAG waves must be derived from a self-consistent treatment of the wave propagation, mixing, and damping.
# 0.0
# In x 5 we show how the analysis system developed in x 3 can be put to practical use by describing the possible behaviors of oscillations in and around the magnetic network and strong magnetic field concentrations, such as sunspots and knots.
# 0.13333333333333333
# This exercise is quite instructive for documenting how incongruent the same oscillations may appear from distinct vantage points and in terms of different combinations of physical variables (i.e., Doppler velocity, intensity fluctuations, etc.).
# 0.075
# A critical summary of our findings and their limitations concludes the paper (x 6).
# 0.0
# 2.
# 0.0
# SURVEY OF THE CALCULATIONS
#
# 5785 K 158 km 8.49 km sÀ1 5/3 4.28 mHz 4.19 mHz 2.74 Â 104 cm sÀ2 1.13 Â 105 g cmÀ1 sÀ2 2.60 Â 10À7 g cmÀ3
#
# The basic magnetic configuration consists of a large unipolar magnetic flux concentration surrounded on each side by two smaller concentrations of opposite-polarity field.
# 0.07142857142857142
# The extent of the dominant flux concentration is approximately 2.0 Mm; the satellites are some 750 km wide.
# -0.25
# As illustrated by Figure 1, all three concentrations have a roughly Gaussian distribution of normal magnetic field strength.
# 0.024999999999999994
# Outside the flux system, the magnetic field runs parallel to the lower (photospheric) boundary.
# 0.0
# All four calculations possess identical hydrostatic isothermal atmospheres.
# 0.0
# The characteristic parameters are the same as those employed in Paper I, and for easy reference they are set out in Table 1.
# 0.12222222222222223
# The base of the computational domain is representative of the solar surface.
# -0.8
# The top of the computational domain is situated at an altitude of 1.26 Mm.
# 0.5
# Attention is restricted to altitudes below 1.2 Mm in the plots we present to avoid spurious numerical artifacts associated with the upper boundary of the computational domain.
# 0.0
# There are 294 computational zones in the vertical direction, yielding a numerical resolution of approximately 4.3 km per zone.
# -0.4
# There are 500 zones in the horizontal direction with a resolution of 15.8 km per zone (see Table 2).
# 0.0
# The lateral extent of the computational domain covers just under 8 Mm, or the equivalent of 4­6 granules.
# 0.0
# We stress that the computations are two-dimensional: there are no
# TABLE 2 Numerical Simulation Parameters Independent Variable x-coordinate ............ y-coordinate............. z-coordinate............. t-coordinatea ............ Piston period............ Piston frequency ...... Piston amplitude ...... Piston location .........
# -0.05
# Number of Zones/Steps 500 1 294 100­198 Extent of Zone/Step 15.8 km 1 4.33 km 1.3 s 23.8 s 42.9 mHz 400 m sÀ1 3.55­3.95 Mm
#
# Range/Duration 7.90 Mm 1 1.26 Mm 130­257 s
#
# In this paper we shall examine and analyze four different calculations.
# 0.0
# Several properties are common to all: the magnetic fields are potential and have the same relative distribution of magnetic field along the lower photospheric boundary of the computational domain (Fig.
# -0.06
# 1), and no field is allowed to thread the two side boundaries.
# 0.0
# All calculations therefore have identical magnetic field line systems.
# 0.0
# 3 This works out to some 2.5 Gbytes of information.
# 0.0
# Fortunately, significant intellectual data compression is possible!
# 0.225
# a The time step used within the numerical simulations is set by the Courant condition on the basis of the maximum value of the fast-wave phase speed.
# 0.0
# It is variable but is considerably less than the uniform sampling cadence of 1.3 s used in all the plots.
# -0.16666666666666666
# Spurious reflections from the upper boundary generally limit the useful temporal duration of each of the four simulations.
# 0.11666666666666665
# Transverse driving in the weak field has the shortest duration, 130 s, while radial driving in the weak field has the longest duration, 257 s. The simulations with the strong magnetic field lie intermediate between these two extremes, with durations of 192 s (transverse driving) and 209 s (radial driving).
# -0.10555555555555557
# No.
# 0.0
# 1, 2003
#
# WAVES IN MAGNETIZED SOLAR ATMOSPHERE.
# 0.0
# II.
# 0.0
# 629
#
# Fig.
# 0.0
# 1.--Distribution of the initial normal magnetic field, Bz , across the bottom (black solid line) and the top (black dashed line) of the computational domain.
# 0.05277777777777778
# The analogous Bx curves, deduced from the potential magnetic field extrapolation, are plotted in red.
# 0.0
# The vertical dotted line segments show the approximate boundaries of the three magnetic flux concentrations: the central flux concentration is about 2 Mm wide, and the satellite reverse-polarity flux concentrations are approximately 750 km in extent.
# -0.225
# The stippled rectangle indicates the location of the photospheric driving piston.
# 0.0
# The piston is roughly 400 km across.
# -0.1
# The magnetic fields plotted here apply to the two strong-field calculations (xx 3.1, 3.4); for the two weak-field calculations (xx 3.2, 3.3) the field strengths are everywhere reduced by a factor of 4 (see also Table 3).
# 0.0
# motions or components of the magnetic field in the direction normal to the data presented in the x-z plots that follow.
# 0.15
# The critical implication of this restriction is that the inter´ n wave is completely decoupled from mediate or shear Alfve the fast and slow MAG waves and therefore plays no further role in our discussion.
# 0.0
#  À 1 D D D D D ð 1Þ ð 2Þ ð 3Þ ð 4Þ ð 5Þ
#
# where all symbols have their usual interpretation.4
#
# 4 This is not the exact set we use in the code, because some viscous dissipation is included in the momentum equation to regularize the computations at the smallest resolved spatial scales.
# 0.225
# Likewise, an equation for the internal energy is actually employed in place of the specific entropy.
# 0.0
# These distinctions, however, are unimportant for this discussion.
# -0.4
# Periodic boundary conditions are applied on the side walls of the domain.
# 0.0
# A wave-transmitting boundary condition is enforced at the upper (chromospheric) boundary.
# 0.0
# In practice, a rather simple-minded procedure is employed to project the motions onto the local Riemann characteristics in the overlying `` ghost zones.''
# 0.0
# The content of the incoming characteristics is set to zero to eliminate unwanted reflections and to suppress spurious wave sources at the upper boundary.
# 0.0
# The strategy is usually adequate for the low- fast wave.
# 0.17777777777777778
# The steepened low- slow waves unfortunately suffer significant reflection from the upper boundary.
# -0.085
# Efforts are currently underway to remedy this limiting condition.
# 0.0
# The unavoidable reflection of waves back into the computational domain sets an upper limit on the useful temporal duration of the simulations to something on the order of 10 wave periods or less.
# 0.03333333333333333
# On the lower (photospheric) boundary, the horizontal velocity and the vertical velocity are specified as prescribed functions of time in the underlying ghost zones.
# 0.0
# The magnetic footpoints are line-tied to the imposed plasma motions.
# 0.0
# Outside the stippled region shown in Figure 1, this prescription is simply that both components of the fluid velocity are zero.
# 0.0
# Within the 400 km wide stippled region-- the position of the localized wave source--the imposed motions are uniform and describe a pure sinusoid in time.
# 0.057142857142857134
# The driving frequency is always 42 mHz, or equivalently a period of 23.8059 s. This is the same frequency/period employed in Paper I.
# 0.0
# 630
# TABLE 3 Survey of the Four Calculations Driving Radial ............. Transverse ...... Weak Field
#
# BOGDAN ET AL.
# -0.375
# Vol.
# 0.0
# 599
#
# Strong Field
#
# x 3.2, Figs.
# 0.4333333333333333
# 10­17, 25­29, 31 x 3.1, Figs.
# 0.0
# 2­9, 23­27, 30 x 3.3, Figs.
# 0.0
# 18­22, 25­27 x 3.4, Figs.
# 0.0
# 23­27
#
# We retain this high-frequency (but here localized in space) wave source for two reasons.
# 0.0
# First, the corresponding wavelength for the low- fast wave just fits into the computational domain.5 At lower frequencies the wavelength would be larger, so both the upper transmitting boundary condition and our ability to analyze the propagation characteristics in an 8 Â 1.25 Mm domain would be severely compromised.
# 0.09
# The reason is, of course, purely pragmatic.
# 0.21428571428571427
# Second, given that the computational domain is necessarily a factor of 10 smaller in extent than one would wish to capture the essential wave dynamics of a sunspot, for example, by employing a period that is too small by the same factor of 10 (i.e., 42 vs. 4.2 mHz), one at least retains a correct relative scaling.
# -0.06875
# In other words, the complex relationships between the morphology of the wave trains and the large-scale magnetic fields present in these simulations mimic those found in sunspots for the 5 minute oscillations.
# -0.14166666666666666
# This follows because the characteristic propagation speeds--the sound ´ n velocity a--are basically the same for speed c and the Alfve our small magnetic flux sheet and a large sunspot.
# 0.059523809523809534
# The isomorphism is imperfect, however, because we cannot rescale the density scale height and the gravitational acceleration in a similar manner.
# 0.0
# Thus, upward-propagating low- slow (acoustic) waves steepen and shock `` sooner '' in a sunspot than in the scaled version studied in these calculations.
# -0.15000000000000002
# Likewise the interesting dynamics that come into play when the oscillation frequency is close to the acoustic cutoff and Brunt-Va ¨ isa ¨ la ¨ frequencies cannot be addressed in this paper.
# 0.5
# The second reason is therefore still based in pragmatism, but it attempts to salvage some aspects of the physical problems suggested by solar observations.
# 0.0
# It remains, therefore, to describe what allows one to distinguish between the four calculations.
# 0.0
# The differences are in the overall strength of the magnetic field and in the nature of the wave driving in the stippled region shown in Figure 1.
# 0.0
# For two of the four calculations, the magnetic field strength is given by the two solid curves plotted in Figure 1.
# 0.0
# We call these the `` strong-field '' cases.
# 0.0
# For the remaining two calcu5 This is particularly evident from a subsequent examination of Figs.
# 0.125
# 4, 6, and 7.
#
# lations, the magnetic field is everywhere reduced by a factor of 4.
# 0.0
# These are the `` weak-field '' cases.
# 0.0
# One should keep in mind that the actual magnetic lines of force are identical for the weak- and strong-field cases.6 What is different is the location and orientation of the  ¼ 1 magnetic canopy layer.
# -0.125
# This distinction has a remarkable and quite profound impact on the wave activity in and about the magnetic flux concentration.
# 0.4166666666666667
# For two of the calculations, the horizontal velocity is also set to zero inside the stippled region, and the vertical velocity varies sinusoidally with a given amplitude.
# 0.0
# In other words, the photosphere moves up and down like a classical piston.
# -0.09351851851851851
# The waves are thus generated by `` radial driving.''
# 0.0
# For the remaining two calculations, the prescriptions for the vertical and horizontal velocities are exchanged, so the waves are generated by `` transverse driving '' at the photosphere.
# 0.0
# This is basically equivalent to shaking the embedded magnetic field lines back and forth at the photospheric boundary.
# 0.0
# Real solar wave sources are likely to present some superposition of radial and transverse driving motions.
# 0.06666666666666667
# The two extreme conditions selected here bracket the actual possibilities.
# -0.0625
# Each of the four calculations corresponds to a unique combination of choices for the magnetic field strength and what might be termed the `` polarization '' (radial or transverse driving) of the wave source.
# 0.375
# The full matrix of possibilities is presented in Table 3.
# 0.35
# 3.
# 0.0
# ANALYSIS OF THE CALCULATIONS
#
# In this section we embark on a general discussion of the wave generation, propagation, transformation, and interference manifest in each of the four representative calculations.
# 0.05000000000000002
# We first take up a strong-field case, in which the low- plasma extends down to the lower (photospheric) boundary within the interior of the dominant flux concentration.
# 0.03148148148148147
# This squeezes the high- plasma into the lower left and right corners of the computational domain.
# 0.14857142857142858
# An important consequence of this separation is that most magnetic lines of force originating in the dominant flux concentration do not thread the  ¼ 1 magnetic canopy; none of the magnetic field lines connected to the wave source intersect the canopy.
# 0.45
# The important conclusion is that waves guided along the magnetic field from the source have no opportunity to interact with the magnetic canopy and transform into other waveforms.
# 0.1375
# We then turn to the two weak-field cases.
# 0.0
# In these examples, the magnetic canopy runs across the entire lateral
# 6
#
# A point that we repeatedly emphasize throughout the discussion.
# 0.0
# TABLE 4 Magneto-Atmospheric-Gravity Waves Plasma High- ..............
# 0.16
# Low- ...............
# a
#
# Fast Wave Acoustic-gravity wave, phase speed: c, quasi-longitudinalb Magneto-sonic wave, phase speed: a, quasi-longitudinalb D
#
# Intermediate Wavea ´ n wave, phase speed: Alfve a, transversec ´ n wave, phase speed: Alfve a, transversec
#
# Slow Wave Guided along B, phase speed: a, transversec Guided along B , phase speed: c, longitudinald
#
# ´ n waves are not considered in our two-dimensional simulations.
# -0.2833333333333334
# Alfve The wavevector, k  , where ðx; tÞ is the phase of the wave, is fairly well (but not perfectly) aligned with the plasma velocity u.
# 0.09999999999999998
# The deviation between k and u generally depends on the angle between k and B .
# 0.05000000000000002
# c Also incompressible, i.e., x u % 0. d Also irrotational, i.e., µ u % 0.
# b
#
# D
#
# D
#
# No.
# 0.0
# 1, 2003
#
# WAVES IN MAGNETIZED SOLAR ATMOSPHERE.
# 0.0
# II.
# 0.0
# 631
#
# extent of the computational domain.
# 0.0
# It dips within the dominant magnetic flux concentration, but it rarely falls below an altitude of 450 km.
# 0.3
# Most magnetic lines of force that emanate from the dominant flux concentration must intersect the magnetic canopy.
# 0.5
# On the other hand, the field lines emerging from the satellite reverse-polarity concentrations do not reach the mode-mixing zone but instead return to the photosphere in the flanks of the dominant-polarity region.
# -0.125
# Unlike the strong-field examples, the wave source is magnetically well connected to the canopy.
# 0.0
# The subsequent discussions make frequent use of the characteristic properties of fast and slow MAG waves in ´ of their attributes high- and low- plasmas.
# 0.013333333333333327
# A short resume are set out in Table 4 to aid the reader in following the deductive reasoning and mode identifications.
# 0.0
# 3.1.
# 0.0
# Strong-Field and Radial Driving
# 3.1.1.
# 0.0
# Low- Slow Waves
#
# essentially identical when viewed as density, pressure (i.e., internal energy density, e), or temperature fluctuations.
# -0.07500000000000001
# In Figure 2 we provide a color rendering of the component of the fluid velocity parallel to the instantaneous magnetic field, uk ðx; zÞ, at a time t ¼ 58:5 s from the start of the simulation.
# 0.0
# Because the piston period is 23.8 s, just over two and a half cycles of the driver have elapsed.
# -0.16666666666666666
# This is clearly reflected in the two slabs of descending material (red ) sandwiched between the three layers of upward-moving fluid ( yellow).
# 0.025000000000000005
# The linear low- slow wave propagates at the adiabatic sound speed cðx; z; t ¼ 0Þ  c0 ¼ 8:49 km sÀ1.
# 0.033333333333333326
# Accordingly, in Figure 2 we measure uk in units of c0 .
# 0.0
# As it progresses upward into regions of decreasing density, the velocity amplitude should increase in proportion to the inverse square root of the density.
# 0.0
# This well-known scaling is a consequence of one definition of the wave energy density,
#  p0 2 !
# 0.0
# 4 ð 6Þ
#
# The oscillating piston generates both fast and slow waves.
# -0.05000000000000002
# We begin by examining the slow waves.
# -0.30000000000000004
# In the low- plasma the slow MAG wave is an acoustic disturbance channeled along the magnetic field lines.
# -0.15000000000000002
# The principal fluctuations associated with this disturbance are plasma motions aligned with the prevailing magnetic field, and alternating compression and rarefaction zones caused by the divergence of the fluid velocity.
# 0.0
# Since our simulation employs an adiabatic energy equation, the compressions and rarefactions are
#
# where N is the Brunt-Va ¨ isa ¨ la ¨ frequency, N2 ¼ g g2 À 2 ; H c ð 7Þ
#
# and H is the density scale height (here 158 km).
# 0.0
# The four
#
# Fig.
# 0.0
# 2.--Rendering of uk ðx; zÞ=c0 at an elapsed time of t ¼ 58:5 s, for radial driving in the strongly magnetized atmosphere (x 3.1).
# 0.4333333333333333
# The thin black lines represent random magnetic field lines: the two thick black lines are the field lines that attach to the edges of the driving piston.
# -0.3066666666666667
# The thin white lines are iso­plasma -contours, labeled by their appropriate value.
# 0.033333333333333326
# The thick white lines mark the location of the  ¼ 1 magnetic canopy.
# -0.15000000000000002
# The red lines locate two fiducial altitudes (499 and 993 km) and a lateral location (3.81 Mm) that figure in the subsequent analysis and later figures.
# 0.0
# This image shows the low- slow MAG wave.
# -0.15000000000000002
# It is collimated by the magnetic field and is confined to the flux that connects back directly to the photospheric driving piston.
# 0.05
# There is some modest wave steepening occurring above z ¼ 300 km, but the Mach numbers of the upward- and downward-flowing material do not exceed 0.123 and 0.107, respectively, at this epoch.
# 0.03333333333333333
# The peak Mach number imparted to the fluid by the driving piston is 0.047.
# 0.0
# 632
#
# BOGDAN ET AL.
# 0.0
# Vol.
# 0.0
# 599
#
# contributions to the energy density are the kinetic, the internal (thermal), the buoyancy (gravitational potential), and the magnetic components.
# 0.0
# The operator D is defined by Df ðx; z; tÞ  f ðx; z; tÞ À f ðx; z; t ¼ 0Þ  f ðx; z; tÞ À f0 ðx; zÞ ; ð 8Þ
#
# and f denotes any of the dependent variables (i.e., , p, u, and B ).
# 0.0
# In ideal linear MHD, the wave energy density is related to the wave energy flux through a canonical conservation law, D @ Ewave þ @t where F wave  Dpu þ 1 1 ðB 0 x DB Þu À ðu x DBÞB 0 : 4 4 ð10Þ
# x F wave
#
# ¼0;
#
# ð 9Þ
#
# The last two terms are simply the Poynting flux.
# 0.225
# Other combinations of (Ewave , F wave ) consistent with equation (9) are in fact readily derived.
# 0.10833333333333334
# Therein lies a particularly sticky point, to which we shall subsequently return in x 4.
# 0.08333333333333333
# At the atmospheric base, the driving piston imparts a 400 m sÀ1 peak-to-peak velocity to the fluid (a Mach number of u=c0 ¼ 0:047).
# -0.26666666666666666
# There are approximately eight density scale heights in the domain, so if Ewave remained strictly constant with altitude, then velocity amplitudes on the order of 21 km sÀ1 would be anticipated by an altitude of z ¼ 1:2 Mm.
# -0.2
# In other words, the motions associated with the slow wave would attain values comparable to the sound speed by an altitude of 960 km.
# -0.00833333333333334
# In practice, nonlinear effects come into play before either of these critical altitudes is reached.
# 0.0
# The waveform is continually distorted by the u x u term in the momentum equation.
# 0.0
# Its principal function is to cause the portion of the wave train profile with a fluid velocity u to advance at the speed u þ c. In this fashion, the disturbances associated with the faster motions of the driving piston eventually overtake the slower propagating disturbances.
# 0.0
# The initial sinusoid is thus distorted into an N-wave (Earnshaw 1860; Courant & Friedrichs 1948; Westervelt 1950; Blackstock 1962; Naugol'nykh 1971; Whitham 1974; Anile et al.
# 0.0
# 1993).
# 0.0
# In a stratified atmosphere, both the nonlinear advection and the density falloff with height act in concert to steepen and distort the wave profile (Einaudi 1970; Anile, Mulone, & Pluchino 1980).
# 0.0
# The formation of a shock discontinuity occurs when adjacent characteristics eventually intersect.
# 0.0
# For an adiabatic simple wave in an isothermal atmosphere, formulae for shock formation heights have been given by Stein & Schwartz (1972) and Anile et al.
# 0.0
# (1980).
# 0.0
# When viscous dissipation is present, strict discontinuities are not attained, but rather a sharp but continuous transition forms.
# -0.0625
# As Fay (1931) remarked, `` Since the effect of viscosity is to attenuate the higher frequency components more than the lower, there is always a waveform having the harmonic components in a stable relation such that the decrease in relative magnitude of any component due to viscosity is compensated by the relative increase due to nonlinearity '' (Rankine 1870; Rayleigh 1910; Fay 1931; Blackstock 1965; Hammerton & Crighton 1989).
# 0.07142857142857142
# This evolutionary scenario is basically corroborated by the results of the numerical simulation displayed in Figures 2­4.
# 0.0
# With Figure 3 we provide a color rendering of the fractional density fluctuations, Dðx; zÞ=0 ðzÞ, at a later elapsed time t ¼ 123:5 s. This plot encompasses a restricted region D
#
# of the computational domain; it also conveys a realistic aspect ratio between the vertical and horizontal scales.
# 0.08333333333333333
# As expected, the slow waves are still well contained within the magnetic flux that is directly connected to the piston.7 Very slight extensions of the wave fronts beyond this flux bundle are visible.
# -0.12916666666666668
# In this regard it is interesting to observe the continuations of the  -contours to the right of the vertical bounding magnetic field line (at x % 3:96 Mm).
# 0.39285714285714285
# Beyond this boundary, the contours no longer simply follow the density fluctuations (compare the  ¼ 0:01 and 0.032 contours), as they are forced to do throughout the interior of the pistonconnected magnetic flux.8 From this we may surmise that sensible magnetic field fluctuations are present beyond the boundary of the flux bundle.
# -0.10000000000000002
# Some weak boundary coupling into the fast wave is present here.
# -0.05833333333333333
# In Figure 4, we focus on the wave steepening and distortion that is taking place along the vertical red line (x ¼ 3:81 Mm) prominently marked on Figures 2 and 3.
# 0.05
# It would of course be preferable to view this evolution along a fixed magnetic field line.
# 0.1
# This would entail interpolating the x-z grid onto an A-z grid, where A is the vector potential.
# 0.0
# Since the piston driving is uniform and the magnetic field is mostly vertical over the piston, there is only a minor disadvantage in simply looking along a line of constant x instead of a line of constant A.
# 0.075
# We shall thus pursue this path of least resistance.
# -0.3
# The basic format of Figure 4 is similar in many respects to that of Figures 2 and 3, except that the elapsed time now runs along the abscissa.
# 0.16666666666666666
# The contours of constant plasma  move up and down in altitude with the passage of the compressions and rarefactions, but we have not plotted the magnetic field lines.
# -0.07777777777777779
# Fractional density fluctuations are again displayed in this figure.
# 0.0
# The distortion of the symmetric sinusoidal waveform (below z ¼ 200 km, say) into the N-wave is easy to see.
# 0.43333333333333335
# The first slow-wave compression and rarefaction are particularly instructive.
# 0.20833333333333331
# The solid black line provides a reference for upward propagation at c0 ¼ 8:49 km sÀ1.
# -0.08333333333333333
# Note how the upward-propagating compression pulls away from the linear wave trajectory, while the rarefaction slowly falls behind this pace.
# -0.35000000000000003
# The thin red lines are close to the linear portion of the waveform and therefore nicely parallel the heavy black line.
# -0.15333333333333335
# In the corner above the heavy dot-dashed black line, the upward-propagating slow waves suffer fairly regular modulation in both space and time.
# -0.13333333333333336
# In this corner, slow waves that have reflected from the upper boundary of the computational domain (z ¼ 1:26 Mm) interfere with the main wave train.
# -0.04444444444444446
# Figure 5 presents these same data in a different format.
# 0.0
# The continuous curves plotted in this figure show the instantaneous state of the atmosphere at x ¼ 3:81 Mm for the time t ¼ 123:5 s, that is to say, the profiles along the vertical red line marked in Figure 4.
# 0.05
# One now sees better the steepening through the transformation from a sinusoid below z ¼ 150 km to an N-wave profile above 300 km.9 The density contrast and the parallel Mach number (Fig.
# 0.16666666666666666
# 5, solid black curve
#
# 7 The magnetic field lines that bound the piston-connected magnetic flux are shown as thick black lines in Figs.
# -0.15833333333333333
# 2, 3, and subsequent figures.
# 0.0
# 8 Within the piston-connected flux bundle, there are essentially no magnetic field fluctuations associated with the slow wave.
# -0.15000000000000002
# The fluctuations in  therefore derive entirely from the variations in the fluid pressure, which are in turn directly tied to the density through the condition of isentropy and the caloric relation.
# 0.03333333333333333
# 9 Recall that the ambient density scale height is 158 km.
# 0.0
# No.
# 0.0
# 1, 2003
#
# WAVES IN MAGNETIZED SOLAR ATMOSPHERE.
# 0.0
# II.
# 0.0
# 633
#
# Fig.
# 0.0
# 3.--Relative density fluctuations Dðx; zÞ=0 ðzÞ at an elapsed time of t ¼ 123:5 s. Black, white, and red lines serve the same functions as in Fig.
# -0.041666666666666664
# 2.
# 0.0
# Only a small portion of the computational domain is shown.
# -0.125
# It is selected to realistically portray the correct spatial aspect ratio.
# 0.0
# The fortuitous break in the color table around 0.004 allows one to discern the weakest density fluctuations that extend beyond the magnetic flux connected directly to the driving piston.
# 0.1
# This snapshot again shows only the low- slow MAG wave, and relative to the view presented in Fig.
# -0.07500000000000001
# 2 the nonlinear distortion of the wave fronts is well developed.
# 0.1
# The iso­ contours display a sequence of steps as a consequence of the density enhancements and depletions present in the wave train.
# 0.0
# Even at this rather advanced and quite nonlinear stage, one sees that the slow wave is basically confined to the piston-connected magnetic flux.
# 0.04999999999999999
# on bottom) saturate at rather modest values because of the viscosity present in the simulation.
# 0.05
# With only 294 computational zones in the vertical direction, the spatial extent of the N-wave front is bounded from below by 3­5 zones, or 10­20 km.
# 0.0
# This limits the continued growth of the compression ratio across these sharp transitions.
# -0.125
# The point is further illustrated by the two curved dashed lines that outline the envelope of the parallel Mach number in the lower panel.
# 0.0
# À2=7 and the lower by The upper line is fitted by uk =c $ 0 À2=5 uk =c $ À0 .
# 0.0
# Both fall decidedly short of the the À1=2 uk =c / 0 scaling expected for an ideal linear wave.
# 0.26666666666666666
#  À 1ÞM 2 þ 2 ð11Þ
#
# where the subscripts distinguish quantities upstream (+) and downstream (À) from the shock, M U À uþ ; cþ ð12Þ
#
# is the shock Mach number, and U is the shock speed in the fixed frame of the atmosphere.
# 0.1
# Using the data provided in Table 1 and the information presented in Figure 5, we may assign shock Mach numbers of 1.24 and 1.26 to the two strongest shocks on the basis of the observed compression ratios.
# 0.0
# Note that this is consistent with U % c0 because of the infall of material into the shock (uþ < 0) from the rarefaction of the previous cycle.
# 0.04166666666666667
# The instantaneous profiles (reckoned at t ¼ 123:5 s) are surrounded by a swarm of small dots.
# -0.25
# These dots show all values of Dðx; z; tÞ=0 ðzÞ (Fig.
# 0.0
# 5, top), uk ðx; z; tÞ=cðx; z; tÞ (bottom; black dots), and u?
# 0.16666666666666669
# ðx; z; tÞ=cðx; z; tÞ (bottom; red dots) recorded at x ¼ 3:81 Mm.
# 0.0
# In all, 160 values are present at each altitude with uniform sampling (Dt ¼ 1:3 s) over 209 s. This display effectively delineates the amplitude envelope of the wave train.
# 0.3
# With the density fluctuations, one finds a prominent asymmetry between the maximal positive and negative density fluctuation excursions.
# 0.14242424242424243
# The asymmetry may be characterized by a `` zero offset,'' ðzÞ, defined as the arithmetic mean of the maximum and minimum values of D=0 recorded at each altitude.
# -0.3125
# The variation with altitude of this quantity is provided by the overplotted solid red curve of Figure 5 (top).
# 0.16666666666666666
# While these data show a fair amount of scatter, which results from the coarse time sampling and the restricted duration of the simulation, a clear trend with altitude is nevertheless present.
# 0.19999999999999998
# For the most part, it is reasonable to associate the zero offset, ðzÞ, with the longtime average of Dðz; tÞ=0 ðzÞ.
# 0.18333333333333332
# The association clearly goes awry near the base of the atmosphere, where the piston intrudes into the computational domain, and also above an altitude of approximately 800 km.
# -0.2
# This latter discrepancy occurs because the initial compressive pulse propagates into a quiescent atmosphere, whereas the subsequent compressions overrun the rarefactions associated with the second half of the previous oscillation cycle.
# -0.05555555555555555
# The first pulse is therefore capable of attaining
#
# 634
#
# BOGDAN ET AL.
# 0.225
# Vol.
# 0.0
# 599
#
# Fig.
# 0.0
# 4.--Altitude vs. time slice of the fractional density fluctuations Dðz; tÞ=0 ðzÞ as recorded at x ¼ 3:81 Mm (Figs.
# 0.0
# 2 and 3; vertical red line).
# 0.0
# The thin white lines are contours of constant values of the plasma , and they are observed to periodically move up and down in altitude with the passage of the compressions and rarefactions of the slow wave.
# -0.17111111111111113
# The solid black line that passes through the origin gives the trajectory of a linear acoustic wave launched at t ¼ 0 that travels vertically at the sound speed c0 ¼ 8:49 km sÀ1.
# 0.07777777777777779
# The two broken black lines do the same for downward-propagating waves launched from the upper boundary of the computational domain (z ¼ 1:26 Mm) at two different times.
# -0.11333333333333333
# The steepening of the first slow wave is illustrated both by the evolution of the density profile across the front from sinusoidal to linear and by the tendency for the compressed N-wave front to propagate faster than c0 , while the rarefacted rear travels more slowly.
# 0.03749999999999998
# Some slow waves are reflected back into the domain and produce the weak modulation in the corner above and to the right of the dot-dashed line.
# -0.07785714285714287
# Two additional red contours are overplotted (at Æ10À3) to bring out the weakest density fluctuations that outrun the slow-wave train.
# 0.0
# These structures are due to the low- fast MAG wave.
# 0.025000000000000005
# larger density enhancements and flow Mach numbers than the subsequent N-waves.
# 0.0
# This is evident from Figure 4.
# 0.25
# One might remedy this problem by discarding the excessive values associated with the first pulse, but the crudeness of the ensuing analysis does not justify such efforts.
# 0.0
# In the estimates that follow we will be content to avoid regions where the association is clearly unreliable.
# 0.10000000000000002
# With the exception of a slight deficit aloft, between the altitudes of 370 and 570 km, this association implies a general increase of the atmospheric density above the piston.
# -0.02916666666666666
# This may be interpreted as a lifting of the atmosphere because of momentum transfer between the wave train and the fluid.
# 0.0
# One commonly attributes this to a `` pressure gradient '' associated with the waves (Gail, Cuntz, & Ulmschneider 1990; Litwin & Rosner 1998).
# -0.3
# Conservation of mass requires a region where the density is depleted just adjacent to the piston.
# 0.0
# The zero offset fails to capture this nuance.
# -0.5
# ...
# 0.0
# The necessary input ingredients are knowledge of the magnetic field, through extrapolation or by direct measurement, and the distribution of pressure and density.
# 0.05
# The magnetic canopy partitions the magneto-atmosphere into contiguous volumes of high- and low- plasma.
# 0.08
# Within these simply connected domains information and energy may be propagated by any one of the MAG waves listed in Table 4.
# 0.0
# For the two-dimensional simulations studied here the fast and slow waves are effectively decoupled from each other within the separate high- and low- domains.
# 0.06214285714285713
# All couplings and transformations are restricted to the environs of the magnetic canopy, which also functions as the domain wall.
# 0.0
# In two dimensions, therefore, one enjoys this very elegant and extremely powerful conceptual advantage of treating each wave variety separately within a contiguous high- or low- area and then working out the couplings and transformations across quasi­ one-dimensional magnetic canopy boundaries.
# 0.27749999999999997
# It may be remarked that all the analysis presented in xx 3 and 5 is based on the repeated application of this technique.
# 0.0
# Although we have reasonable theoretical facility in propagating the two waves through the domains, what we lack for the present is a robust set of rules that permit us to connect the waves across the magnetic canopy (Carlsson& Stein 1999).
# 0.06666666666666667
# In the examples presented here, the numerical simulation has done this for us as a by-product of its direct solution of the primitive equations.
# 0.1
# We should almost be able to dispense with the numerics, at least in a qualitative context, if we could develop connection formulae to tell us how much transmitted high- slow and fast waves are created when a low- fast wave is incident on the canopy, for example.
# 0.0825
# The mode conversion studied here and in Paper I have provided some hints as to what might be important control parameters, viz., the relative alignment (or lack thereof) between B , , and the local wavevector k. But we are still far from assembling these pieces into a coherent and predictive picture.
# 0.2
# ´n In three spatial dimensions, the (intermediate) Alfve wave mixes with the fast and slow waves.
# -0.05000000000000002
# The prevailing evidence suggests that this coupling is not simply restricted to the  % 1 domain boundaries.
# 0.0
# Rather there are numerous calculations of ULF waves in the magnetosphere, for example, which indicate that the fast and the ´ n waves remain coupled throughout the (shear) Alfve entire volume of low- plasma (Singer et al.
# 0.05
# 1981; Southwood & Hughes 1983; Kivelson & Southwood 1985, 1986; Murata 1986; Inhester 1987; Lee & Lysak 1990; Wright 1992; Cheng et al.
# 0.0
# 1993; Walker 1998).
# 0.0
# A comprehensive study of this larger set of MAG wave couplings in the solar and stellar atmospheric context must await a future contribution in this series.
# 0.0625
# D
#
# The examination of the synthetic observations carried out in x 5 leaves the overwhelming impression that a little knowledge is indeed a dangerous thing in the realm of data interpretation.
# -0.09583333333333333
# The best advice one can give is to be aware of the regions surrounding the place where the observations are obtained (Gary 2001; McIntosh et al.
# 0.625
# 2001; McIntosh & Judge 2001).
# 0.0
# It is imperative to determine whether the spectral line or continuum is formed in a low- or high- plasma.
# 0.08
# But this alone is not sufficient.
# 0.0
# One must also be able to infer the close approaches of the magnetic canopy and to know whether the canopy resides above or below the site where the data are from.
# 0.25
# It is also essential to determine where the magnetic flux passing through the observing layer connects at the photosphere or perhaps even above in the corona.
# 0.0
# Next, the location of the wave sources and their dominant state of polarization (radial vs. transverse driving motions) must be ascertained (Musielak & Rosner 1987; Collins 1989a, 1989b, 1992; McKenzie 1991; Lee 1993).
# 0.0
# The lateral proximity of the wave source to the observation point need not be the overriding factor.
# 0.0
# The magnetic field may divert waves from nearby sources away from the observed region or connect it to distant sites of profuse wave activity.
# -0.1
# Reliable information on the wanderings of the magnetic canopy is particularly helpful in determining how much or little attention may be required in tracking down distant sources.
# -0.06909722222222223
# Finally, it is paramount to be aware that as many as three waves are moving information and energy through the magneto-atmosphere and that each wave contributes in different ways to the integrated intensity and Doppler signals.
# 0.1875
# The differences are not only related to the structure of the atmosphere and the orientation of the wave trains but also to the perspective of the observer.
# 0.0
# The different wave varieties often follow distinct routes between their source and a common observation point.
# 0.0
# This opens the way for a rich magneto-acoustic tomography of the solar atmosphere.
# 0.375
# The parallels are indeed somewhat closer with the terrestrial seismic discipline (where one employs both P and S waves) than for the better developed program of local helioseismology within the solar envelope and interior (where only p-modes are currently considered).
# 0.09999999999999999
# In the weak-field regions surrounding magnetic flux concentrations we found two wave trains: a coronal `` rain '' of downward-propagating fast waves and the direct horizontally traveling `` surface '' or `` ground '' fast wave.
# 0.16666666666666666
# The former arrives before the latter because it takes advantage of the high wave speed in the overlying low- top layer.
# 0.132
# Within the magnetic flux concentration the fast-wave train arrives before the slow-wave train.
# 0.0
# There are better opportunities here for separating their contributions to observations because they have rather different phase speeds and wavelengths and they emphasize distinct combinations of dependent variables.
# 0.26666666666666666
# The ratio of fast-to-slow wave amplitude depends both on the nature of the source and whether the magnetic field lines that connect back to the source region pass through the magnetic canopy.
# 0.0
# We also identified some regions with very complex oscillations.
# -0.39
# Along the two-dimensional  ¼ 1 magnetic canopy one can at each point determine a radius of curvature and thereby construct a circle tangent to the canopy that employs this radius of curvature.
# -0.1
# Our simulations suggest that the most complex wave fields are found within this tangent circle when (1) it resides within the high- plasma and
#
# No.
# 0.12
# 1, 2003
#
# WAVES IN MAGNETIZED SOLAR ATMOSPHERE.
# 0.0
# II.
# 0.0
# 659
# (2) it corresponds to a local minimum in the radius of curvature along the magnetic canopy.
# 0.0
# Under these circumstances, high- fast waves with a wide range of propagation directions are expected in the tangent circle.
# 0.04
# If the magnetic field is also well aligned with  , then high- slow waves are also prevalent.
# -0.07000000000000002
# The essential point is that a diverse variety of waves pass through these regions.
# 0.0
# This observational counsel comes with two caveats.
# 0.0
# First, it is based on the assumption that the wave source is coherent for many wave periods.
# 0.4166666666666667
# This is a critical prerequisite for the complex but stable interference patterns present in our simulations.
# -0.09999999999999999
# The fundamental reason is that these interferences are often between slower disturbances created during the initial cycles of the piston, with the faster disturbances generated later in time.
# 0.0
# Without the phase locking between early and late times, the interference patterns become transitory in space and in time.
# -0.09999999999999999
# The coherence time of the source therefore limits the distance to which the stable interference patterns can exist.
# 0.0
# Second, the interference patterns are also predicated on the various waves being able to survive their circuitous journeys from the source.
# 0.16666666666666666
# We know that radiative D
#
# transfer is likely to have a profound effect on MHD waves with a strong compressive character (Bogdan et al.
# 0.1722222222222222
# 1996).
# 0.0
# Likewise, there is increasing attention to the role of Hall ´ nic disturbanand Pedersen conductivities in damping Alfve ces in the upper chromosphere and solar corona (Campos 1998; Campos & Mendes 2000; DePontieu, Martens, & Hudson 2001; Vogt 2002).
# 0.0
# Many other dissipation mechanisms abound, but none of them are included in our four numerical experiments.
# 0.1875
# This work was supported by Norwegian Research Council grant 146467/420, Solar and Heliospheric Plasmas, by grant ATM-0139977 from the National Science Foundation (NSF), and by a grant from the National Aeronautics and Space Administration.
# 0.0
# T. J.
# 0.0
# B. expresses his sincere thanks for the kind hospitality of Spiro Antiochos and his colleagues at the Naval Research Laboratory and for the strong support and encouragement of Richard Behnke and the Upper Atmospheric Research Section of the NSF.
# 0.28888888888888886
# The thoughtful suggestions and counsel of the referee, Zdzislaw Musielak, are gratefully acknowledged.
# 0.4
# REFERENCES Kivelson, M. G., & Southwood, D. J.
# 0.0
# 1985, Geophys.
# 0.0
# Res.
# 0.0
# Lett., 12, 49 Anile, A. M., Hunter, J. K., Patano, P., & Russo, G. 1993, Ray Methods ------.
# 0.0
# 1986, J. Geophys.
# 0.0
# Res., 91, 4345 for Nonlinear Waves in Fluids and Plasmas (New York: Wiley) Klein, R. I., Stein, R. F., & Kalkofen, W. 1978, ApJ, 220, 1024 Anile, A. M., Mulone, G., & Pluchino, S. 1980, Wave Motion, 2, 267 Kudoh, T., & Shibata, K. 1999, ApJ, 514, 493 Axelsson, P. 2000, Nonlinearity, 13, 19 Lamb, H. 1908, Proc.
# 0.13636363636363635
# London Math.
# 0.0
# Soc., 7, 122 Barnes, A.
# 0.0
# 1992, J. Geophys.
# 0.0
# Res., 97, 12,105 ------.
# 0.0
# 1910, Proc.
# 0.0
# R. Soc.
# 0.0
# London A, 84, 551 Belie ¨ n, A. J. C., Martens, P. C. H., & Keppens, R. 1999, ApJ, 526, 478 Lee, D.-H., & Lysak, R. L. 1990, Geophys.
# 0.0
# Res.
# 0.0
# Lett., 17, 53 Belie ¨ n, A. J. C., Poedts, S., & Goedbloed, J. P. 1997, A&A, 322, 995 Lee, J. W. 1993, ApJ, 404, 372 Blackstock, D. T. 1962, J. Acoustic Soc.
# 0.0
# Am., 34, 9 Leibacher, J., Gouttebroze, P., & Stein, R. F. 1982, ApJ, 258, 393 ------.
# 0.0
# 1965, J. Acoustic Soc.
# 0.0
# Am., 39, 1019 Leroy, B.
# 0.0
# 1985, Geophys.
# 0.0
# Appl.
# 0.0
# Fluid Dyn., 32, 123 Bo, L., & Wang, S. 2001, Chinese Astron.
# 0.0
# Astrophys., 25, 194 Leroy, B., & Schwartz, S. J.
# 0.0
# 1982, A&A, 112, 84 Bodo, G., Kalkofen, W., Massaglia, S., & Rossi, P. 2000, A&A, 354, 296 Litwin, C., & Rosner, R. 1998, ApJ, 506, L143 Bogdan, T. J., Kno ¨ lker, M., MacGregor, K. B., & Kim, E.-J.
# 0.0
# 1996, ApJ, Mariska, J. T., & Hollweg, J. V. 1985, ApJ, 296, 746 456, 879 McIntosh, S. W., & Judge, P. G. 2001, ApJ, 561, 420 Bogdan, T. J., et al.
# 0.0
# 2002, Astron.
# 0.0
# Nachr., 323, 196 McIntosh, S. W., et al.
# 0.0
# 2001, ApJ, 548, L237 Bois, P. A.
# 0.0
# 1976, J.
# 0.0
# Mec., 15, 781 McKenzie, J. F. 1991, J. Geophys.
# 0.0
# Res., 96, 9491 Borovikov, V. A.
# 0.0
# 1996, J. Appl.
# 0.0
# Math.
# 0.0
# Mech., 60, 521 Murata, H. 1986, J.
# 0.0
# Plasma Phys., 36, 243 Bray, R. J., & Loughhead, R. E. 1974, The Solar Chromosphere (London: Musielak, Z. E., & Rosner, R. 1987, ApJ, 315, 371 Chapman and Hall), 252  adez  , V. M., & Ballester, J. M. 1994, A&A, 292, 669 Nakariakov, V. M., Verwichte, E., Berghmans, D., & Robbrecht, E. 2000, C  adez  , V. M., Oliver, R., & Ballester, J. M. 1996, A&A, 307, 947 A&A, 362, 1151 C Naugol'nykh, K. A.
# 0.0
# 1971, in High-Intensity Ultrasonic Fields, ed.
# 0.0
# Campos, L. M. B. C. 1998, Theoret.
# 0.0
# Comput.
# 0.0
# Fluid Dyn., 10, 37 L. D. Rozenberg (New York: Plenum), 5 Campos, L. M. B. C., & Mendes, P. M. V. M. 2000, J.
# 0.06818181818181818
# Plasma Phys., 63,  il, D., & Karlicky ´ , M. 2000, A&A, 359, 766 Odstrc 221 Ofman, L., & Davila, J. M. 1998, J. Geophys.
# 0.0
# Res., 103, 23,677 Cannon, C. J.
# 0.0
# 1974, J. Quant.
# 0.0
# Spectrosc.
# 0.0
# Radiat.
# 0.0
# Transfer, 14, 761 Ofman, L., Nakariakov, V. M., & DeForest, C. E. 1999, ApJ, 514, 441 Cargill, P. J., Spicer, D. S., & Zalesak, S. T. 1997, ApJ, 488, 854 Ofman, L., Nakariakov, V. M., & Sehgal, N. 2000, ApJ, 533, 1071 Carlsson, M., & Stein, R. F. 1992, ApJ, 397, L59 Ofman, L., & Thompson, B. J.
# 0.0
# 2002, ApJ, 574, 440 ------.
# 0.0
# 1995, ApJ, 440, L29 Oliver, R., & Ballester, J. L. 1995, ApJ, 448, 444 ------.
# 0.0
# 1997, ApJ, 481, 500 ------.
# 0.0
# 2002, Sol.
# 0.0
# Phys., 206, 45 ------.
# 0.0
# 1999, in ASP Conf.
# 0.0
# Ser.
# 0.0
# 184, Third Advances in Solar Europhysics Pelinovskii, E. N., & Petrukhin, N. S. 1988, Soviet Astron., 32, 457 Conference: Magnetic Fields and Oscillations, ed.
# 0.0
# B. Schmeider, ------.
# 0.0
# 1994, Geophys.
# 0.0
# Astrophys.
# 0.0
# Fluid Dyn., 75, 77 A. Hofmann, & J. Staude (San Francisco: ASP), 206 Rankine, W. J. M. 1870, Philos.
# 0.0
# Trans.
# 0.0
# R. Soc.
# 0.0
# London, 160, 277 ------.
# 0.0
# 2002, ApJ, 572, 626 Rayleigh, L. 1910, Proc.
# 0.0
# R. Soc.
# 0.0
# London A, 84, 247 Cheng, C. Z., Chang, T. C., Lin, C. A., & Tsai, W. H. 1993, J. Geophys.
# 0.0
# Rosenthal, C. S., et al.
# 0.0
# 2002, ApJ, 564, 508 (Paper I) Res., 98, 11,339 Ruderman, M. S., Nakariakov, V. M., & Roberts, B.
# 0.0
# 1998, A&A, 338, 1118 Cole, J. D., & Greifinger, C. 1969, J. Geophys.
# 0.0
# Res., 75, 193 Saito, T., Kudoh, T., & Shibata, K. 2001, ApJ, 554, 1151 Collins, W. 1989a, ApJ, 337, 548 Sakai, J.-I., Igarashi, J., & Kawata, T. 1998, Sol.
# 0.0
# Phys., 181, 13 ------.
# 0.0
# 1989b, ApJ, 343, 499 Sakai, J. I., Mizuhata, Y., Kawata, T., & Cramer, N. F. 2000, ApJ, 544, ------.
# 0.0
# 1992, ApJ, 384, 319 1108 Courant, R., & Friedrichs, K. O.
# 0.0
# 1948, Supersonic Flow and Shock Waves ------.
# 0.0
# 2001, ApJ, 550, 1075 (New York: Wiley) Schmitz, F., & Fleck, B.
# 0.13636363636363635
# 1995, A&A, 301, 483 Crighton, D. G., & Lee-Bapty, I. P. 1992, Wave Motion, 15, 315 Schwartz, R. A., & Stein, R. F. 1975, ApJ, 200, 499 DePontieu, B., Martens, P. C. H., & Hudson, H. S. 2001, ApJ, 558, 859 Shibata, K. 1983, PASJ, 35, 263 Earnshaw, S. 1860, Philos.
# 0.0
# Trans.
# 0.0
# R. Soc.
# 0.0
# London, 150, 133 Singer, H. J., Southwood, D. J., Walker, R. J., & Kivelson, M. G. 1981, Einaudi, F. 1969, Phys.
# 0.0
# Fluids, 12, 752 J. Geophys.
# 0.0
# Res., 86, 4589 ------.
# 0.0
# 1970, J. Geophys.
# 0.0
# Res., 75, 193 Southwood, D. J., & Hughes, W. J.
# 0.0
# 1983, Space Sci.
# 0.0
# Rev., 35, 301 Fay, R. D. 1931, J. Acoustic Soc.
# 0.0
# Am., 3, 222 Stein, R. F. 1968, ApJ, 154, 297 Ferraro, V. C. A., & Plumpton, C. 1958, ApJ, 129, 459 ° , T., Habbal, S. R., Holzer, T. E., & Leer, E. 1984, ApJ, 280, 382 Stein, R. F., & Schwartz, R. A.
# 0.0
# 1972, ApJ, 177, 807 Fla ------.
# 0.0
# 1973, ApJ, 186, 1083 Gail, H.-P., Cuntz, M., & Ulmschneider, P. 1990, A&A, 234, 359 Sterling, A. C., & Hollweg, J. V. 1988, ApJ, 327, 950 Gary, G. A.
# 0.0
# 2001, Sol.
# 0.0
# Phys., 203, 71 Sutmann, G., Musielak, Z. E., & Ulmschneider, P. 1998, A&A, 340, 556 Hammerton, P. W., & Crighton, D. G. 1989, Proc.
# 0.0
# R. Soc.
# 0.0
# London A, 426, Terradas, J., Oliver, R., & Ballester, J. L. 1999, ApJ, 517, 488 125 Theurer, J., Ulmschneider, P., & Cuntz, M. 1997, A&A, 324, 587 Inhester, B.
# 0.0
# 1987, J. Geophys.
# 0.0
# Res., 92, 4751 Tsiklauri, D., & Nakariakov, V. M. 2001, A&A, 379, 1106 Kaburaki, O., & Uchida, Y.
# 0.0
# 1971, PASJ, 23, 405 Vogt, J.
# 0.0
# 2002, Surv.
# 0.0
# Geophys., 23, 335 Kato, S. 1966, ApJ, 144, 326
#
# 660
#
# BOGDAN ET AL.
# 0.0
# Whitham, G. B.
# 0.0
# 1974, Linear and Nonlinear Waves (New York: Wiley) Wright, A. N. 1992, J. Geophys.
# 0.13636363636363635
# Res., 97, 6429 Wu, S. T., Zheng, H., Wang, S., Thompson, B. J., Plunkett, S. P., Zhao, X. P., & Dryer, M. 2001, J. Geophys.
# 0.0
# Res., 106, 25,089 Yih, C.-S. 1974, Phys.
# 0.0
# Fluids, 17, 1489
#
# Wait, J. R. 1974, J. Geophys.
# 0.0
# Res., 79, 5055 Walker, A. D. M. 1998, J. Atmos.
# 0.0
# Sol.-Terr.
# 0.0
# Phys., 60, 1279 Webb, G. M., Woodward, T. I., Brio, M., & Zank, G. P. 1993, J.
# 0.0
# Plasma Phys., 49, 465 Westervelt, P. J.
# 0.0
# 1950, J. Acoustic Soc.
# 0.0
# Am., 22, 319
# 0.0

# %%
blob.words.count('magnetic')
# Out:
# 261
